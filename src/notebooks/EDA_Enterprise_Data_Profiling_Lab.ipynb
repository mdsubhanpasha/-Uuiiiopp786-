# %% [markdown]
# # NAYEEM-ELDF: EDA Enterprise Data Profiling Lab
# Interactive inspection and profiling notebook for live data fabric telemetry.

# %%
import os
import sys
import pandas as pd

sys.path.insert(0, os.path.abspath("../.."))
from src.orchestration.enterprise_orchestration_pipeline_controller import run_master_enterprise_pipeline

data = run_master_enterprise_pipeline()
df = data["telemetry"]
df.head()

# %%
df.info()
df.describe()
